# %% [markdown]
# # WeatherPy Submission
#
# ---
#
# ### Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ## Generate the Cities List by Using the citipy Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lons = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lon_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lons = np.random.uniform(lon_range[0], lon_range[1], size=1500)
lat_lons = zip(lats, lons)

# Identify nearest city for each lat, lng combination
for lat_lon in lat_lons:
    city = citipy.nearest_city(lat_lon[0], lat_lon[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# # Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the starter code

# %%
# Set the API base URL | FROM DOCUMENTATION
# url = f'https://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}'
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city | FROM DOCUMENTATION
    # city_url = url+'&q={city name}'
    

    # Log the url, record, and set numbers | 
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count | 
    record_count += 1

    # Run an API request for each of the cities 
    response = requests.get(query_url + city).json()
    try:
        # Parse the JSON and retrieve data
        city_weather = response

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date | FROM DOCUMENTATION
        city_lat = city_weather['coord']['lat']
        city_lon = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lon": city_lon,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rabigh
# Processing Record 2 of Set 1 | kilindoni
# Processing Record 3 of Set 1 | cunen
# Processing Record 4 of Set 1 | tazacorte
# Processing Record 5 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | almenara
# Processing Record 8 of Set 1 | constantia
# Processing Record 9 of Set 1 | port-aux-francais
# Processing Record 10 of Set 1 | adamstown
# Processing Record 11 of Set 1 | kailua-kona
# Processing Record 12 of Set 1 | fortuna
# Processing Record 13 of Set 1 | sesheke
# Processing Record 14 of Set 1 | plastun
# Processing Record 15 of Set 1 | talnakh
# Processing Record 16 of Set 1 | newman
# Processing Record 17 of Set 1 | invercargill
# Processing Record 18 of Set 1 | udachny
# Processing Record 19 of Set 1 | harper
# Processing Record 20 of Set 1 | st. john's
# Processing Record 21 of Set 1 | lorengau
# Processing Record 22 of Set 1 | waitangi
# Processing Record 23 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 24 of Set 1 | papatowai
# Processing Record 25 of Set 1 | ribeira grande
# Processing Record 26 of Set 1 | grytviken
# Processing Record 27 of Set 1 | ust-nera
# Processing Record 28 of Set 1 | ola
# Processing Record 29 of Set 1 | utrik
# Processing Record 30 of Set 1 | naze
# Processing Record 31 of Set 1 | alofi
# Processing Record 32 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | laojunmiao
# Processing Record 35 of Set 1 | georgetown
# Processing Record 36 of Set 1 | baiyin
# Processing Record 37 of Set 1 | olonkinbyen
# Processing Record 38 of Set 1 | tarauaca
# Processing Record 39 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 40 of Set 1 | nagqu
# Processing Record 41 of Set 1 | kuala belait
# Processing Record 42 of Set 1 | longyearbyen
# Processing Record 43 of Set 1 | liliani
# Processing Record 44 of Set 1 | purranque
# Processing Record 45 of Set 1 | iskateley
# Processing Record 46 of Set 1 | bredasdorp
# Processing Record 47 of Set 1 | edinburgh of the seven seas
# Processing Record 48 of Set 1 | ilulissat
# Processing Record 49 of Set 1 | putina
# Processing Record 50 of Set 1 | fengxiang
# Processing Record 0 of Set 2 | remire-montjoly
# Processing Record 1 of Set 2 | bilibino
# Processing Record 2 of Set 2 | tromso
# Processing Record 3 of Set 2 | iqaluit
# Processing Record 4 of Set 2 | whitehorse
# Processing Record 5 of Set 2 | tual
# Processing Record 6 of Set 2 | kuanda
# Processing Record 7 of Set 2 | carnarvon
# Processing Record 8 of Set 2 | puerto natales
# Processing Record 9 of Set 2 | kingston
# Processing Record 10 of Set 2 | tobi village
# City not found. Skipping...
# Processing Record 11 of Set 2 | boguchany
# Processing Record 12 of Set 2 | pionerskiy
# Processing Record 13 of Set 2 | palencia
# Processing Record 14 of Set 2 | pisco
# Processing Record 15 of Set 2 | indianola
# Processing Record 16 of Set 2 | blackmans bay
# Processing Record 17 of Set 2 | berdigestyakh
# Processing Record 18 of Set 2 | sisimiut
# Processing Record 19 of Set 2 | rio preto da eva
# Processing Record 20 of Set 2 | nova sintra
# Processing Record 21 of Set 2 | keflavik
# Processing Record 22 of Set 2 | choibalsan
# Processing Record 23 of Set 2 | kayangel
# Processing Record 24 of Set 2 | boise
# Processing Record 25 of Set 2 | kudahuvadhoo
# Processing Record 26 of Set 2 | wajir
# Processing Record 27 of Set 2 | ponta delgada
# Processing Record 28 of Set 2 | jamestown
# Processing Record 29 of Set 2 | cannonvale
# Processing Record 30 of Set 2 | moose jaw
# Processing Record 31 of Set 2 | berezovyy
# Processing Record 32 of Set 2 | mount pearl
# Processing Record 33 of Set 2 | atbasar
# Processing Record 34 of Set 2 | kone
# Processing Record 35 of Set 2 | hermanus
# Processing Record 36 of Set 2 | wewak
# Processing Record 37 of Set 2 | vanimo
# Processing Record 38 of Set 2 | masterton
# Processing Record 39 of Set 2 | maceio
# Processing Record 40 of Set 2 | mumbwa
# Processing Record 41 of Set 2 | reguiba
# Processing Record 42 of Set 2 | tura
# Processing Record 43 of Set 2 | qaqortoq
# Processing Record 44 of Set 2 | dhidhdhoo
# Processing Record 45 of Set 2 | la ronge
# Processing Record 46 of Set 2 | segezha
# Processing Record 47 of Set 2 | la'ie
# Processing Record 48 of Set 2 | lebu
# Processing Record 49 of Set 2 | roma
# Processing Record 0 of Set 3 | karratha
# Processing Record 1 of Set 3 | sirte
# Processing Record 2 of Set 3 | porto novo
# Processing Record 3 of Set 3 | taoudenni
# Processing Record 4 of Set 3 | taltal
# Processing Record 5 of Set 3 | sinabang
# Processing Record 6 of Set 3 | tranovaho
# City not found. Skipping...
# Processing Record 7 of Set 3 | port mathurin
# Processing Record 8 of Set 3 | afaahiti
# Processing Record 9 of Set 3 | devinuwara
# City not found. Skipping...
# Processing Record 10 of Set 3 | vorgashor
# Processing Record 11 of Set 3 | hawaiian paradise park
# Processing Record 12 of Set 3 | nogliki
# Processing Record 13 of Set 3 | selfoss
# Processing Record 14 of Set 3 | sao vicente
# Processing Record 15 of Set 3 | gemena
# Processing Record 16 of Set 3 | qarah zia' od din
# Processing Record 17 of Set 3 | vilyuchinsk
# Processing Record 18 of Set 3 | goba
# Processing Record 19 of Set 3 | ryotsu-minato
# Processing Record 20 of Set 3 | ghanzi
# Processing Record 21 of Set 3 | enewetak
# Processing Record 22 of Set 3 | daru
# Processing Record 23 of Set 3 | yellowknife
# Processing Record 24 of Set 3 | haiku-pauwela
# Processing Record 25 of Set 3 | buy
# Processing Record 26 of Set 3 | la passe
# Processing Record 27 of Set 3 | urangan
# Processing Record 28 of Set 3 | redencao
# Processing Record 29 of Set 3 | hithadhoo
# Processing Record 30 of Set 3 | beitbridge
# Processing Record 31 of Set 3 | geraldton
# Processing Record 32 of Set 3 | at taj
# Processing Record 33 of Set 3 | plettenberg bay
# Processing Record 34 of Set 3 | acarau
# Processing Record 35 of Set 3 | rodolfo sanchez taboada
# Processing Record 36 of Set 3 | hasaki
# Processing Record 37 of Set 3 | axim
# Processing Record 38 of Set 3 | floro
# Processing Record 39 of Set 3 | hammerfest
# Processing Record 40 of Set 3 | luderitz
# Processing Record 41 of Set 3 | i-n-salah
# Processing Record 42 of Set 3 | cartagena
# Processing Record 43 of Set 3 | tiksi
# Processing Record 44 of Set 3 | puerto ayora
# Processing Record 45 of Set 3 | letterkenny
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | ostroleka
# Processing Record 48 of Set 3 | vimmerby
# Processing Record 49 of Set 3 | puerto deseado
# Processing Record 0 of Set 4 | as sulayyil
# Processing Record 1 of Set 4 | saint croix
# Processing Record 2 of Set 4 | hirado
# Processing Record 3 of Set 4 | horta
# Processing Record 4 of Set 4 | antsiranana
# Processing Record 5 of Set 4 | lompoc
# Processing Record 6 of Set 4 | mermoz boabab
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | thompson
# Processing Record 9 of Set 4 | vorkuta
# Processing Record 10 of Set 4 | albany
# Processing Record 11 of Set 4 | ketchikan
# Processing Record 12 of Set 4 | port elizabeth
# Processing Record 13 of Set 4 | zdolbuniv
# Processing Record 14 of Set 4 | avarua
# Processing Record 15 of Set 4 | san jose village
# City not found. Skipping...
# Processing Record 16 of Set 4 | yaren
# Processing Record 17 of Set 4 | chicxulub puerto
# City not found. Skipping...
# Processing Record 18 of Set 4 | wailua homesteads
# Processing Record 19 of Set 4 | pelotas
# Processing Record 20 of Set 4 | el bolson
# Processing Record 21 of Set 4 | papao
# Processing Record 22 of Set 4 | kodiak
# Processing Record 23 of Set 4 | atafu village
# Processing Record 24 of Set 4 | mejit
# Processing Record 25 of Set 4 | progreso
# Processing Record 26 of Set 4 | hamilton
# Processing Record 27 of Set 4 | gao
# Processing Record 28 of Set 4 | itacoatiara
# Processing Record 29 of Set 4 | narasapur
# Processing Record 30 of Set 4 | susuman
# Processing Record 31 of Set 4 | badger
# Processing Record 32 of Set 4 | mount gambier
# Processing Record 33 of Set 4 | nikolayevsk-on-amure
# Processing Record 34 of Set 4 | dudinka
# Processing Record 35 of Set 4 | college
# Processing Record 36 of Set 4 | babai
# Processing Record 37 of Set 4 | manado
# Processing Record 38 of Set 4 | sakaiminato
# Processing Record 39 of Set 4 | sinan
# Processing Record 40 of Set 4 | bereznik
# Processing Record 41 of Set 4 | isafjordur
# Processing Record 42 of Set 4 | isangel
# Processing Record 43 of Set 4 | lerwick
# Processing Record 44 of Set 4 | happy valley-goose bay
# Processing Record 45 of Set 4 | labrador city
# Processing Record 46 of Set 4 | fort st. john
# Processing Record 47 of Set 4 | port blair
# Processing Record 48 of Set 4 | albina
# Processing Record 49 of Set 4 | revda
# Processing Record 0 of Set 5 | pyt-yakh
# Processing Record 1 of Set 5 | salekhard
# Processing Record 2 of Set 5 | el nido
# Processing Record 3 of Set 5 | kalix
# Processing Record 4 of Set 5 | ak"yar
# City not found. Skipping...
# Processing Record 5 of Set 5 | shahrak
# Processing Record 6 of Set 5 | saipan
# Processing Record 7 of Set 5 | punta arenas
# Processing Record 8 of Set 5 | cam ranh
# Processing Record 9 of Set 5 | sagaing
# Processing Record 10 of Set 5 | sankt johann in tirol
# Processing Record 11 of Set 5 | izhmorskiy
# Processing Record 12 of Set 5 | lagoa
# Processing Record 13 of Set 5 | klyuchi
# Processing Record 14 of Set 5 | ayaguz
# City not found. Skipping...
# Processing Record 15 of Set 5 | port lincoln
# Processing Record 16 of Set 5 | pundong
# Processing Record 17 of Set 5 | fairfield
# Processing Record 18 of Set 5 | ancud
# Processing Record 19 of Set 5 | mineiros
# Processing Record 20 of Set 5 | al hazm
# Processing Record 21 of Set 5 | prince rupert
# Processing Record 22 of Set 5 | saudarkrokur
# Processing Record 23 of Set 5 | new plymouth
# Processing Record 24 of Set 5 | spas-demensk
# Processing Record 25 of Set 5 | vila franca do campo
# Processing Record 26 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 27 of Set 5 | great falls
# Processing Record 28 of Set 5 | stanley
# Processing Record 29 of Set 5 | shetpe
# Processing Record 30 of Set 5 | jimma
# Processing Record 31 of Set 5 | port-cartier
# Processing Record 32 of Set 5 | zyryanovsk
# Processing Record 33 of Set 5 | bam
# Processing Record 34 of Set 5 | kladno
# Processing Record 35 of Set 5 | banyo
# Processing Record 36 of Set 5 | tazovsky
# Processing Record 37 of Set 5 | tralee
# Processing Record 38 of Set 5 | asau
# Processing Record 39 of Set 5 | toliara
# Processing Record 40 of Set 5 | burg unter-falkenstein
# City not found. Skipping...
# Processing Record 41 of Set 5 | okoneshnikovo
# Processing Record 42 of Set 5 | port douglas
# Processing Record 43 of Set 5 | margaret river
# Processing Record 44 of Set 5 | kazanskoye
# Processing Record 45 of Set 5 | chonchi
# Processing Record 46 of Set 5 | osmanabad
# Processing Record 47 of Set 5 | mogadishu
# Processing Record 48 of Set 5 | ludvika
# Processing Record 49 of Set 5 | greymouth
# Processing Record 0 of Set 6 | richards bay
# Processing Record 1 of Set 6 | bosansko grahovo
# Processing Record 2 of Set 6 | nar'yan-mar
# Processing Record 3 of Set 6 | viedma
# Processing Record 4 of Set 6 | portland
# Processing Record 5 of Set 6 | tolanaro
# Processing Record 6 of Set 6 | la ceiba
# Processing Record 7 of Set 6 | banikoara
# Processing Record 8 of Set 6 | fort bragg
# Processing Record 9 of Set 6 | kirensk
# Processing Record 10 of Set 6 | pathankot
# Processing Record 11 of Set 6 | harnai
# Processing Record 12 of Set 6 | vladimirovac
# Processing Record 13 of Set 6 | namibe
# Processing Record 14 of Set 6 | kruisfontein
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | isla mujeres
# Processing Record 17 of Set 6 | lata
# Processing Record 18 of Set 6 | berbera
# Processing Record 19 of Set 6 | vodnyy
# Processing Record 20 of Set 6 | carbonear
# Processing Record 21 of Set 6 | andkhoy
# Processing Record 22 of Set 6 | san patricio
# Processing Record 23 of Set 6 | north battleford
# Processing Record 24 of Set 6 | cambria
# Processing Record 25 of Set 6 | vernon
# Processing Record 26 of Set 6 | sur
# Processing Record 27 of Set 6 | rongelap
# Processing Record 28 of Set 6 | sarangani
# Processing Record 29 of Set 6 | ambalangoda
# Processing Record 30 of Set 6 | port saint john's
# Processing Record 31 of Set 6 | hami
# Processing Record 32 of Set 6 | hobyo
# Processing Record 33 of Set 6 | dunedin
# Processing Record 34 of Set 6 | cox's bazar
# Processing Record 35 of Set 6 | peace river
# Processing Record 36 of Set 6 | darwin
# Processing Record 37 of Set 6 | arinos
# Processing Record 38 of Set 6 | goniri
# Processing Record 39 of Set 6 | nakamura
# Processing Record 40 of Set 6 | fale old settlement
# Processing Record 41 of Set 6 | east london
# Processing Record 42 of Set 6 | kasongo-lunda
# Processing Record 43 of Set 6 | baoqing
# Processing Record 44 of Set 6 | saint-joseph
# Processing Record 45 of Set 6 | carupano
# Processing Record 46 of Set 6 | dubbo
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | nizhniy ingash
# Processing Record 49 of Set 6 | northam
# Processing Record 0 of Set 7 | veszto
# Processing Record 1 of Set 7 | chake chake
# Processing Record 2 of Set 7 | byron bay
# Processing Record 3 of Set 7 | walvis bay
# Processing Record 4 of Set 7 | west island
# Processing Record 5 of Set 7 | essaouira
# Processing Record 6 of Set 7 | reshetylivka
# Processing Record 7 of Set 7 | ugoofaaru
# Processing Record 8 of Set 7 | acapulco de juarez
# Processing Record 9 of Set 7 | cidreira
# Processing Record 10 of Set 7 | kisangani
# Processing Record 11 of Set 7 | jayapura
# Processing Record 12 of Set 7 | nieuw amsterdam
# Processing Record 13 of Set 7 | oranjemund
# Processing Record 14 of Set 7 | arraial do cabo
# Processing Record 15 of Set 7 | noosa heads
# Processing Record 16 of Set 7 | marsala
# Processing Record 17 of Set 7 | zhezqazghan
# Processing Record 18 of Set 7 | ardesen
# Processing Record 19 of Set 7 | clearwater
# Processing Record 20 of Set 7 | napili-honokowai
# Processing Record 21 of Set 7 | barcelos
# Processing Record 22 of Set 7 | tabuk
# Processing Record 23 of Set 7 | eregli
# Processing Record 24 of Set 7 | ilha de mocambique
# Processing Record 25 of Set 7 | lihue
# Processing Record 26 of Set 7 | kil'mez'
# City not found. Skipping...
# Processing Record 27 of Set 7 | soe
# Processing Record 28 of Set 7 | new norfolk
# Processing Record 29 of Set 7 | tarariras
# Processing Record 30 of Set 7 | inari
# Processing Record 31 of Set 7 | peniche
# Processing Record 32 of Set 7 | cascais
# Processing Record 33 of Set 7 | bardai
# Processing Record 34 of Set 7 | tsiombe
# Processing Record 35 of Set 7 | karakocan
# Processing Record 36 of Set 7 | saint-pierre
# Processing Record 37 of Set 7 | akrehamn
# Processing Record 38 of Set 7 | kristiansund
# Processing Record 39 of Set 7 | san andres
# Processing Record 40 of Set 7 | khovd
# Processing Record 41 of Set 7 | varena
# Processing Record 42 of Set 7 | hotan
# Processing Record 43 of Set 7 | nguigmi
# Processing Record 44 of Set 7 | turpan
# Processing Record 45 of Set 7 | nadym
# Processing Record 46 of Set 7 | carolina beach
# Processing Record 47 of Set 7 | cornwall
# Processing Record 48 of Set 7 | ikom
# Processing Record 49 of Set 7 | westport
# Processing Record 0 of Set 8 | ilovlya
# Processing Record 1 of Set 8 | gisborne
# Processing Record 2 of Set 8 | vitry-le-francois
# Processing Record 3 of Set 8 | simanggang
# Processing Record 4 of Set 8 | kulhudhuffushi
# Processing Record 5 of Set 8 | solnechnyy
# Processing Record 6 of Set 8 | dabou
# Processing Record 7 of Set 8 | fuxin
# Processing Record 8 of Set 8 | nakasongola
# Processing Record 9 of Set 8 | argo
# Processing Record 10 of Set 8 | mukalla
# Processing Record 11 of Set 8 | taro
# Processing Record 12 of Set 8 | alice springs
# Processing Record 13 of Set 8 | kargasok
# Processing Record 14 of Set 8 | yilan
# Processing Record 15 of Set 8 | chibougamau
# Processing Record 16 of Set 8 | lakes of the four seasons
# Processing Record 17 of Set 8 | natal
# Processing Record 18 of Set 8 | thulamahashi
# Processing Record 19 of Set 8 | kyabe
# Processing Record 20 of Set 8 | argungu
# Processing Record 21 of Set 8 | dongola
# Processing Record 22 of Set 8 | saldanha
# Processing Record 23 of Set 8 | sao joao da barra
# Processing Record 24 of Set 8 | goldap
# Processing Record 25 of Set 8 | umm kaddadah
# Processing Record 26 of Set 8 | larkird
# Processing Record 27 of Set 8 | raduzhny
# Processing Record 28 of Set 8 | koshki
# Processing Record 29 of Set 8 | gadzhiyevo
# Processing Record 30 of Set 8 | la sarre
# Processing Record 31 of Set 8 | chyorny yar
# Processing Record 32 of Set 8 | hard bargain
# Processing Record 33 of Set 8 | colonel hill
# Processing Record 34 of Set 8 | port alfred
# Processing Record 35 of Set 8 | manokwari
# Processing Record 36 of Set 8 | talara
# Processing Record 37 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 38 of Set 8 | mutoko
# Processing Record 39 of Set 8 | thief river falls
# Processing Record 40 of Set 8 | kurkino
# Processing Record 41 of Set 8 | coquimbo
# Processing Record 42 of Set 8 | salaqi
# Processing Record 43 of Set 8 | weno
# Processing Record 44 of Set 8 | pacocha
# Processing Record 45 of Set 8 | forfar
# Processing Record 46 of Set 8 | makarska
# Processing Record 47 of Set 8 | aasiaat
# Processing Record 48 of Set 8 | afua
# Processing Record 49 of Set 8 | purbalingga
# Processing Record 0 of Set 9 | chernyshevskiy
# Processing Record 1 of Set 9 | chui
# Processing Record 2 of Set 9 | banes
# Processing Record 3 of Set 9 | yamada
# Processing Record 4 of Set 9 | pointe-noire
# Processing Record 5 of Set 9 | pandan
# Processing Record 6 of Set 9 | royse city
# Processing Record 7 of Set 9 | beledweyne
# Processing Record 8 of Set 9 | coro
# Processing Record 9 of Set 9 | pathein
# Processing Record 10 of Set 9 | merizo village
# Processing Record 11 of Set 9 | tweed heads
# Processing Record 12 of Set 9 | arish
# Processing Record 13 of Set 9 | sao felix do xingu
# Processing Record 14 of Set 9 | loen
# Processing Record 15 of Set 9 | caleta de carquin
# Processing Record 16 of Set 9 | tokar
# Processing Record 17 of Set 9 | zhangye
# Processing Record 18 of Set 9 | cuenca
# Processing Record 19 of Set 9 | rudnichnyy
# Processing Record 20 of Set 9 | bria
# Processing Record 21 of Set 9 | kudymkar
# Processing Record 22 of Set 9 | amungan
# Processing Record 23 of Set 9 | 'ohonua
# City not found. Skipping...
# Processing Record 24 of Set 9 | visakhapatnam
# Processing Record 25 of Set 9 | jawala mukhi
# Processing Record 26 of Set 9 | gamba
# Processing Record 27 of Set 9 | madinat ash shamal
# Processing Record 28 of Set 9 | pembroke
# Processing Record 29 of Set 9 | the pas
# Processing Record 30 of Set 9 | flin flon
# Processing Record 31 of Set 9 | diego de almagro
# Processing Record 32 of Set 9 | ghat
# Processing Record 33 of Set 9 | yagry
# City not found. Skipping...
# Processing Record 34 of Set 9 | kapuskasing
# Processing Record 35 of Set 9 | sonsorol village
# City not found. Skipping...
# Processing Record 36 of Set 9 | nemuro
# Processing Record 37 of Set 9 | hastings
# Processing Record 38 of Set 9 | cedeira
# Processing Record 39 of Set 9 | yeniseysk
# Processing Record 40 of Set 9 | vingt cinq
# City not found. Skipping...
# Processing Record 41 of Set 9 | teguise
# Processing Record 42 of Set 9 | anadyr
# Processing Record 43 of Set 9 | arkhangel'sk
# Processing Record 44 of Set 9 | kapa'a
# Processing Record 45 of Set 9 | port glaud
# City not found. Skipping...
# Processing Record 46 of Set 9 | zaozersk
# Processing Record 47 of Set 9 | linhares
# Processing Record 48 of Set 9 | pontianak
# Processing Record 49 of Set 9 | itoman
# Processing Record 0 of Set 10 | labytnangi
# Processing Record 1 of Set 10 | howard springs
# Processing Record 2 of Set 10 | kalmunai
# Processing Record 3 of Set 10 | el calafate
# Processing Record 4 of Set 10 | tobelo
# Processing Record 5 of Set 10 | bankim
# Processing Record 6 of Set 10 | severo-yeniseyskiy
# Processing Record 7 of Set 10 | holly springs
# Processing Record 8 of Set 10 | cockburn town
# Processing Record 9 of Set 10 | salinas de hidalgo
# Processing Record 10 of Set 10 | cidade velha
# Processing Record 11 of Set 10 | uturoa
# Processing Record 12 of Set 10 | bejaia
# Processing Record 13 of Set 10 | kesinga
# Processing Record 14 of Set 10 | cuatro cienegas de carranza
# Processing Record 15 of Set 10 | katsuren-haebaru
# Processing Record 16 of Set 10 | esmeralda
# Processing Record 17 of Set 10 | san antonio de pale
# Processing Record 18 of Set 10 | jiagedaqi
# Processing Record 19 of Set 10 | kununurra
# Processing Record 20 of Set 10 | wainwright
# Processing Record 21 of Set 10 | khandyga
# Processing Record 22 of Set 10 | simoes filho
# Processing Record 23 of Set 10 | holualoa
# Processing Record 24 of Set 10 | ba
# City not found. Skipping...
# Processing Record 25 of Set 10 | kill devil hills
# Processing Record 26 of Set 10 | coxim
# Processing Record 27 of Set 10 | bom jesus
# Processing Record 28 of Set 10 | belem de sao francisco
# Processing Record 29 of Set 10 | velez
# Processing Record 30 of Set 10 | marsh harbour
# Processing Record 31 of Set 10 | chancay
# Processing Record 32 of Set 10 | seminole
# Processing Record 33 of Set 10 | bismarck
# Processing Record 34 of Set 10 | mahajanga
# Processing Record 35 of Set 10 | orsa
# Processing Record 36 of Set 10 | sohagpur
# Processing Record 37 of Set 10 | kaa-khem
# Processing Record 38 of Set 10 | reyhanli
# Processing Record 39 of Set 10 | egilsstadir
# Processing Record 40 of Set 10 | ataq
# Processing Record 41 of Set 10 | huarmey
# Processing Record 42 of Set 10 | farmington
# Processing Record 43 of Set 10 | santa terezinha
# Processing Record 44 of Set 10 | nassau
# Processing Record 45 of Set 10 | lincoln city
# Processing Record 46 of Set 10 | qulsary
# Processing Record 47 of Set 10 | tamanrasset
# Processing Record 48 of Set 10 | sarmiento
# Processing Record 49 of Set 10 | port augusta
# Processing Record 0 of Set 11 | nova vicosa
# Processing Record 1 of Set 11 | kangding
# Processing Record 2 of Set 11 | takoradi
# Processing Record 3 of Set 11 | hilo
# Processing Record 4 of Set 11 | krasnoturansk
# Processing Record 5 of Set 11 | watsa
# Processing Record 6 of Set 11 | yorkton
# Processing Record 7 of Set 11 | inyonga
# Processing Record 8 of Set 11 | ladario
# Processing Record 9 of Set 11 | santa ana
# Processing Record 10 of Set 11 | broome
# Processing Record 11 of Set 11 | kidal
# Processing Record 12 of Set 11 | coahuayana de hidalgo
# Processing Record 13 of Set 11 | san luis de la loma
# Processing Record 14 of Set 11 | sumbawa besar
# Processing Record 15 of Set 11 | gladstone
# Processing Record 16 of Set 11 | paradip garh
# Processing Record 17 of Set 11 | akureyri
# Processing Record 18 of Set 11 | south hedland
# Processing Record 19 of Set 11 | khorixas
# Processing Record 20 of Set 11 | nouadhibou
# Processing Record 21 of Set 11 | esqueda
# Processing Record 22 of Set 11 | galle
# Processing Record 23 of Set 11 | bouna
# Processing Record 24 of Set 11 | hengchun
# Processing Record 25 of Set 11 | willowmore
# Processing Record 26 of Set 11 | santo antonio do ica
# Processing Record 27 of Set 11 | key west
# Processing Record 28 of Set 11 | conde
# Processing Record 29 of Set 11 | baruun-urt
# Processing Record 30 of Set 11 | ardabil
# Processing Record 31 of Set 11 | crane
# Processing Record 32 of Set 11 | bolobo
# Processing Record 33 of Set 11 | yanbu
# Processing Record 34 of Set 11 | mili
# Processing Record 35 of Set 11 | mashi
# Processing Record 36 of Set 11 | mpika
# Processing Record 37 of Set 11 | pemangkat
# Processing Record 38 of Set 11 | freetown
# Processing Record 39 of Set 11 | bowen
# Processing Record 40 of Set 11 | minas de marcona
# Processing Record 41 of Set 11 | kiunga
# Processing Record 42 of Set 11 | defuniak springs
# Processing Record 43 of Set 11 | tsiolkovskiy
# City not found. Skipping...
# Processing Record 44 of Set 11 | borinskoye
# Processing Record 45 of Set 11 | kindu
# Processing Record 46 of Set 11 | galliano
# Processing Record 47 of Set 11 | mochudi
# Processing Record 48 of Set 11 | ngama
# Processing Record 49 of Set 11 | wanxian
# Processing Record 0 of Set 12 | polyarnyy
# Processing Record 1 of Set 12 | yabelo
# Processing Record 2 of Set 12 | aktau
# Processing Record 3 of Set 12 | prado
# Processing Record 4 of Set 12 | pangody
# Processing Record 5 of Set 12 | kievka
# Processing Record 6 of Set 12 | maine soroa
# Processing Record 7 of Set 12 | lianjiang
# Processing Record 8 of Set 12 | boditi
# Processing Record 9 of Set 12 | maryborough
# Processing Record 10 of Set 12 | oeiras
# Processing Record 11 of Set 12 | n'zeto
# Processing Record 12 of Set 12 | mafeteng
# Processing Record 13 of Set 12 | tyup
# Processing Record 14 of Set 12 | vrangel'
# Processing Record 15 of Set 12 | kerikeri
# Processing Record 16 of Set 12 | tofol
# Processing Record 17 of Set 12 | yuza
# Processing Record 18 of Set 12 | guatrache
# Processing Record 19 of Set 12 | alesund
# Processing Record 20 of Set 12 | enriquillo
# Processing Record 21 of Set 12 | tillaberi
# Processing Record 22 of Set 12 | franca
# Processing Record 23 of Set 12 | addiet canna
# Processing Record 24 of Set 12 | yangquan
# Processing Record 25 of Set 12 | agidel'
# City not found. Skipping...
# Processing Record 26 of Set 12 | irati
# Processing Record 27 of Set 12 | kachug
# Processing Record 28 of Set 12 | guapiles
# Processing Record 29 of Set 12 | bikenibeu village
# Processing Record 30 of Set 12 | freeport
# Processing Record 31 of Set 12 | san lawrenz
# Processing Record 32 of Set 12 | padang
# Processing Record 33 of Set 12 | olyokminsk
# Processing Record 34 of Set 12 | homer
# Processing Record 35 of Set 12 | bucerias
# Processing Record 36 of Set 12 | manta
# Processing Record 37 of Set 12 | markovo
# Processing Record 38 of Set 12 | zaysan
# Processing Record 39 of Set 12 | zdvinsk
# Processing Record 40 of Set 12 | salumbar
# Processing Record 41 of Set 12 | todos santos
# Processing Record 42 of Set 12 | tranqueras
# Processing Record 43 of Set 12 | nova gradiska
# Processing Record 44 of Set 12 | el abiodh sidi cheikh
# Processing Record 45 of Set 12 | pechora
# Processing Record 46 of Set 12 | seydi
# Processing Record 47 of Set 12 | kenai
# Processing Record 48 of Set 12 | starovelichkovskaya
# Processing Record 49 of Set 12 | guarapari
# Processing Record 0 of Set 13 | songkhla
# Processing Record 1 of Set 13 | borzna
# Processing Record 2 of Set 13 | concepcion del oro
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create DataFrame from city_data_list
weather_data_df = pd.DataFrame(city_data)

# count how many cities were returned
weather_data_df.count()
# Out:
# City          581
# Lat           581
# Lon           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
# return df table
weather_data_df.head()
# Out:
#         City      Lat      Lon  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     rabigh  22.7986  39.0349     92.34        60          53        6.49
# 1  kilindoni  -7.9139  39.6668     76.82        76           2       15.86
# 2      cunen  15.3375 -91.0269     74.80        74          94        5.53
# 3  tazacorte  28.6290 -17.9293     78.15        81          20       10.36
# 4    ushuaia -54.8000 -68.3000     31.62        69          20        2.30
#
#   Country        Date
# 0      SA  1722880540
# 1      TZ  1722880541
# 2      GT  1722880542
# 3      ES  1722880544
# 4      AR  1722880546

# %%
# export weather_data_df to csv 
weather_data_df.index.name = 'City_ID'
weather_data_df.to_csv("city_weather_data.csv")

# %%
# read saved data
city_weather_data = pd.read_csv("city_weather_data.csv")
city_weather_data.head()
# Out:
#    City_ID       City      Lat      Lon  Max Temp  Humidity  Cloudiness  \
# 0        0     rabigh  22.7986  39.0349     92.34        60          53
# 1        1  kilindoni  -7.9139  39.6668     76.82        76           2
# 2        2      cunen  15.3375 -91.0269     74.80        74          94
# 3        3  tazacorte  28.6290 -17.9293     78.15        81          20
# 4        4    ushuaia -54.8000 -68.3000     31.62        69          20
#
#    Wind Speed Country        Date
# 0        6.49      SA  1722880540
# 1       15.86      TZ  1722880541
# 2        5.53      GT  1722880542
# 3       10.36      ES  1722880544
# 4        2.30      AR  1722880546

# %% [markdown]
# # Requirement 1: Create Plots to Showcase the Relationships Between Weather Variables and Latitude

# %%
# read csv file
city_weather_df = pd.read_csv("city_weather_data.csv")

# %% [markdown]
# #### Latitude vs Temperature
# - import Pandas as pd
# - import matplotlib.pyplot as plt

# %%
# create scatter plots
plt.scatter(city_weather_data['Lat'], city_weather_data['Max Temp'])
plt.title('Latitude vs Temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.grid(True)

plt.savefig("Fig1_Submission.png")
plt.show()

# %% [markdown]
# #### Latitude vs Humidity

# %%
# create scatter plots
plt.scatter(city_weather_data['Lat'], city_weather_data['Humidity'])
plt.title('Latitude vs Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)

plt.savefig("Fig2_Submission.png")
plt.show()

# %% [markdown]
# #### Latitude vs Cloudiness

# %%
# create scatter plots
plt.scatter(city_weather_data['Lat'], city_weather_data['Cloudiness'])
plt.title('Latitude vs Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.grid(True)

plt.savefig("Fig3_Submission.png")
plt.show()

# %% [markdown]
# #### Latitude vs Wind Speed

# %%
# create scatter plots
plt.scatter(city_weather_data['Lat'], city_weather_data['Wind Speed'])
plt.title('Latitude vs Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.grid(True)

plt.savefig("Fig4_Submissions.png")
plt.show()

# %% [markdown]
# # Requirement 2: Compute Linear Regression for Each Relationship
